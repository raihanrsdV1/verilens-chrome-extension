# %% [markdown]
# # VideoVeritas — Kaggle T4 GPU (Final Fix)
#
# ### Pre-requisites
# 1. **Internet ON** in Notebook settings
# 2. **GPU → T4 x2** accelerator
# 3. Video dataset added via **Add Input**
#
# ### Why previous attempts failed
# | Attempt | Problem |
# |---|---|
# | Original notebook | `flashinfer` has no sm_75 wheel → runtime crash; wrong backend name `TRITON_ATTN` |
# | v2 (pin vLLM 0.4.3) | 0.4.3 has no Python 3.12 wheel → pip builds from source → fails |
# | v3 (no-deps install) | vLLM is a compiled extension; `--no-deps` doesn't help if the wheel itself doesn't exist |
#
# ### This notebook's approach (the correct one)
# - Install **latest vLLM** — it ships pre-built Python 3.12 wheels ✓
# - **Uninstall flashinfer** AFTER vLLM (flashinfer is optional; removing it is safe)
# - Set `VLLM_ATTENTION_BACKEND=XFORMERS` — xformers supports T4 (sm_75) ✓
# - `--enforce-eager` — disables CUDA graph capture (which needs flash-attn) ✓

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CELL 1 — Install packages
# ═══════════════════════════════════════════════════════════════════════════════

# Step 1: Install vLLM (latest — has proper Python 3.12 wheels)
# This will also pull in flashinfer as a dependency, which is fine;
# we remove it in Step 2 before vLLM ever tries to USE it.
print('Installing vLLM and openai...')
# !pip install -q vllm openai modelscope
print('✓ Install complete')

# Step 2: Remove flashinfer AFTER vLLM is installed.
# flashinfer has no sm_75 (T4) kernel, so it crashes vLLM at startup.
# vLLM treats it as optional — removing it forces vLLM to use xformers instead.
print('\nRemoving flashinfer (no T4/sm_75 support)...')
# !pip uninstall -y flashinfer flashinfer-python 2>/dev/null; echo '✓ flashinfer removed'

# Step 3: Install xformers — the T4-compatible attention backend.
# Must be installed AFTER torch so it links against the right CUDA version.
print('\nInstalling xformers (T4-compatible attention backend)...')
# !pip install -q xformers
print('✓ xformers installed')

# Step 4: Clone VideoVeritas repo
import os
if not os.path.isdir('/kaggle/working/VideoVeritas'):
    print('\nCloning VideoVeritas repo...')
    # !git clone -q https://github.com/EricTan7/VideoVeritas.git /kaggle/working/VideoVeritas
    # !cd /kaggle/working/VideoVeritas && pip install -q -e . --no-deps
else:
    print('\nVideoVeritas already cloned.')

# Verify
print('\n── Verification ──')
# !python -c "import vllm; print('vLLM:', vllm.__version__)"
# !python -c "import xformers; print('xformers:', xformers.__version__)"
# !python -c "import torch; print('torch:', torch.__version__, '| CUDA:', torch.version.cuda)"
# Out:
# Installing vLLM and openai...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 80.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.3/194.3 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.9/360.9 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 66.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.0/161.0 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 99.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 84.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 MB 41.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.7/748.7 kB 41.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.7/530.7 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 101.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 75.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 MB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 103.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 98.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.1/870.1 kB 42.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 74.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 60.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 94.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 67.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 69.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 76.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.7/327.7 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 95.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 MB 44.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.4/467.4 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 MB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.3/29.3 MB 56.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.5/282.5 kB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 95.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 MB 43.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.2/201.2 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 52.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 83.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 89.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 MB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.4/819.4 kB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 30.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# ydata-profiling 4.18.4 requires numba<0.63,>=0.60, but you have numba 0.65.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# pylibcudf-cu12 26.2.1 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# libcuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# rmm-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuml-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.0 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# pylibraft-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cuvs-cu12 26.2.0 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.6 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.5 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.6 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-python<13.0,>=12.9.2, but you have cuda-python 13.3.1 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-toolkit[nvcc,nvrtc]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.0 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# libcuvs-cu12 26.2.0 requires cuda-toolkit[cublas,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# libraft-cu12 26.2.0 requires cuda-toolkit[cublas,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# google-adk 1.29.0 requires starlette<1.0.0,>=0.49.1, but you have starlette 1.2.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# gradio 5.50.0 requires starlette<1.0,>=0.40.0, but you have starlette 1.2.1 which is incompatible.
# ✓ Install complete
#
# Removing flashinfer (no T4/sm_75 support)...
# Found existing installation: flashinfer-python 0.6.11.post2
# Uninstalling flashinfer-python-0.6.11.post2:
#   Successfully uninstalled flashinfer-python-0.6.11.post2
# ✓ flashinfer removed
#
# Installing xformers (T4-compatible attention backend)...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 67.8 MB/s eta 0:00:00
# ✓ xformers installed
#
# Cloning VideoVeritas repo...
#   Preparing metadata (setup.py) ... done
#
# ── Verification ──
# vLLM: 0.22.1
# xformers: 0.0.35
# torch: 2.11.0+cu130 | CUDA: 13.0

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CELL 2 — Download model
# ═══════════════════════════════════════════════════════════════════════════════
from modelscope import snapshot_download
import os

# The model is ~17 GB. ModelScope caches it under /root/.cache.
# We use that path DIRECTLY with vLLM — never copy it.
# /kaggle/working only has ~20 GB free; copying would cause disk-full errors.
CACHE_PATH = '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas'

if os.path.isdir(CACHE_PATH) and len(os.listdir(CACHE_PATH)) > 10:
    print(f'✓ Model already cached at:\n  {CACHE_PATH}')
    model_dir = CACHE_PATH
else:
    print('Downloading VideoVeritas model (~17 GB)…')
    model_dir = snapshot_download('EricTanh/VideoVeritas')
    print(f'✓ Model downloaded to: {model_dir}')

os.environ['MODEL_DIR'] = model_dir
print(f'\nMODEL_DIR = {model_dir}')
# Out:
# Downloading VideoVeritas model (~17 GB)…
# Downloading Model from https://www.modelscope.cn to directory: /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas
# 2026-06-09 19:47:13,052 - modelscope - INFO - Got 18 files, start to download ...
# Processing 18 items:   0%|          | 0.00/18.0 [00:00<?, ?it/s]
# Downloading [generation_config.json]:   0%|          | 0.00/213 [00:00<?, ?B/s]
# Downloading [added_tokens.json]:   0%|          | 0.00/707 [00:00<?, ?B/s]
# Downloading [config.json]:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# Downloading [chat_template.jinja]:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# Downloading [model-00001-of-00004.safetensors]:   0%|          | 0.00/4.65G [00:00<?, ?B/s]
# Downloading [merges.txt]:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Downloading [configuration.json]:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# Downloading [model-00002-of-00004.safetensors]:   0%|          | 0.00/4.58G [00:00<?, ?B/s]
# Downloading [model-00003-of-00004.safetensors]:   0%|          | 0.00/4.58G [00:00<?, ?B/s]
# Downloading [model-00004-of-00004.safetensors]:   0%|          | 0.00/2.52G [00:00<?, ?B/s]
# Downloading [model.safetensors.index.json]:   0%|          | 0.00/66.2k [00:00<?, ?B/s]
# Downloading [preprocessor_config.json]:   0%|          | 0.00/390 [00:00<?, ?B/s]
# Downloading [README.md]:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading [special_tokens_map.json]:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Downloading [tokenizer.json]:   0%|          | 0.00/10.9M [00:00<?, ?B/s]
# Downloading [tokenizer_config.json]:   0%|          | 0.00/5.32k [00:00<?, ?B/s]
# Downloading [video_preprocessor_config.json]:   0%|          | 0.00/817 [00:00<?, ?B/s]
# Downloading [vocab.json]:   0%|          | 0.00/2.65M [00:00<?, ?B/s]
# 2026-06-09 19:49:20,678 - modelscope - INFO - Finish downloading 18 files for repo 'EricTanh/VideoVeritas'
# ✓ Model downloaded to: /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas
#
# MODEL_DIR = /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CELL 3 — GPU info + libcuda stub
# ═══════════════════════════════════════════════════════════════════════════════
import subprocess, os

# Detect available GPUs
res = subprocess.run(
    ['nvidia-smi', '--query-gpu=name,memory.total,compute_cap', '--format=csv,noheader'],
    capture_output=True, text=True
)
gpus = [l.strip() for l in res.stdout.strip().split('\n') if l.strip()]
NUM_GPUS = len(gpus)

print(f'Detected {NUM_GPUS} GPU(s):')
for g in gpus:
    print(f'  • {g}')

# Kaggle ships libcuda.so.1 but vLLM's linker looks for libcuda.so (no .1).
# Create a symlink so linking doesn't fail.
stub_dir = '/kaggle/working/stubs'
os.makedirs(stub_dir, exist_ok=True)
res2 = subprocess.run(
    ['find', '/usr', '/usr/local', '-name', 'libcuda.so.1', '-maxdepth', '12'],
    capture_output=True, text=True
)
paths = [p for p in res2.stdout.strip().split('\n') if p]
if paths:
    dst = f'{stub_dir}/libcuda.so'
    if not os.path.lexists(dst):
        os.symlink(paths[0], dst)
    print(f'✓ libcuda.so stub → {paths[0]}')
else:
    print('WARNING: libcuda.so.1 not found — proceeding anyway')

os.environ['NUM_GPUS']        = str(NUM_GPUS)
os.environ['LIBRARY_PATH']    = f'{stub_dir}:' + os.environ.get('LIBRARY_PATH', '')
os.environ['LD_LIBRARY_PATH'] = f'{stub_dir}:' + os.environ.get('LD_LIBRARY_PATH', '')
print(f'✓ tensor-parallel-size will be {NUM_GPUS}')

# Quick disk check
print('\n── Disk usage ──')
# !df -h /root /kaggle/working
# Out:
# Detected 2 GPU(s):
#   • Tesla T4, 15360 MiB, 7.5
#   • Tesla T4, 15360 MiB, 7.5
# ✓ libcuda.so stub → /usr/local/nvidia/lib64/libcuda.so.1
# ✓ tensor-parallel-size will be 2
#
# ── Disk usage ──
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         7.9T  6.9T  1.1T  87% /
# /dev/loop1       20G   41M   20G   1% /kaggle/working

# %%
import subprocess, sys, os

res = subprocess.run([sys.executable, '-c', 'import vllm; print(vllm.__version__)'],
                     capture_output=True, text=True)
vllm_version = res.stdout.strip()
print(f'vLLM version: {vllm_version}')

model_dir = os.environ['MODEL_DIR']
num_gpus  = os.environ['NUM_GPUS']
stub_dir  = '/kaggle/working/stubs'

res2 = subprocess.run(['which', 'vllm'], capture_output=True, text=True)
vllm_bin = res2.stdout.strip() or 'vllm'
print(f'vllm binary: {vllm_bin}')

script = f"""#!/usr/bin/env bash
set -euo pipefail

export VLLM_USE_V1=0
export VLLM_ATTENTION_BACKEND=XFORMERS
export VLLM_USE_FLASHINFER_SAMPLER=0
export VLLM_USE_FLASHINFER=0
export LIBRARY_PATH={stub_dir}:${{LIBRARY_PATH:-}}
export LD_LIBRARY_PATH={stub_dir}:${{LD_LIBRARY_PATH:-}}

echo "[vLLM] model   = {model_dir}"
echo "[vLLM] n_gpus  = {num_gpus}"
echo "[vLLM] backend = XFORMERS (T4 compatible)"

{vllm_bin} serve "{model_dir}" \\
    --enforce-eager \\
    --port 8000 \\
    --host 0.0.0.0 \\
    --dtype half \\
    --tensor-parallel-size {num_gpus} \\
    --max-model-len 32768 \\
    --gpu-memory-utilization 0.90 \\
    --limit-mm-per-prompt '{{"video": 1}}' \\
    --trust-remote-code
"""

path = '/kaggle/working/start_vllm.sh'
with open(path, 'w') as f:
    f.write(script)
os.chmod(path, 0o755)
print(f'\n✓ Launch script written')
print(script)
# Out:
# vLLM version: 0.22.1
# vllm binary: /usr/local/bin/vllm
#
# ✓ Launch script written
# #!/usr/bin/env bash
# set -euo pipefail
#
# export VLLM_USE_V1=0
# export VLLM_ATTENTION_BACKEND=XFORMERS
# export VLLM_USE_FLASHINFER_SAMPLER=0
# export VLLM_USE_FLASHINFER=0
# export LIBRARY_PATH=/kaggle/working/stubs:${LIBRARY_PATH:-}
# export LD_LIBRARY_PATH=/kaggle/working/stubs:${LD_LIBRARY_PATH:-}
#
# echo "[vLLM] model   = /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas"
# echo "[vLLM] n_gpus  = 2"
# echo "[vLLM] backend = XFORMERS (T4 compatible)"
#
# /usr/local/bin/vllm serve "/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas" \
#     --enforce-eager \
#     --port 8000 \
#     --host 0.0.0.0 \
#     --dtype half \
#     --tensor-parallel-size 2 \
#     --max-model-len 32768 \
#     --gpu-memory-utilization 0.90 \
#     --limit-mm-per-prompt '{"video": 1}' \
#     --trust-remote-code

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CELL 5 — Launch vLLM server
# ═══════════════════════════════════════════════════════════════════════════════
import subprocess, os, time

log_path = '/kaggle/working/vllm.log'

# Kill any existing instance
subprocess.run(['pkill', '-f', 'vllm'], capture_output=True)
time.sleep(2)

log_fh = open(log_path, 'w')
proc = subprocess.Popen(
    ['/kaggle/working/start_vllm.sh'],
    stdout=log_fh,
    stderr=subprocess.STDOUT,
    env=os.environ.copy()   # pass ALL env vars set in previous cells
)

# Wait 5s — if it crashed instantly, show the log immediately
time.sleep(5)
log_fh.flush()

if proc.poll() is not None:
    print(f'✗ Server exited immediately (rc={proc.poll()}). Log:')
    with open(log_path) as f:
        print(f.read())
else:
    print(f'✓ vLLM server is starting (PID={proc.pid})')
    print(f'  Log file: {log_path}')
    print('\nFirst log lines:')
    with open(log_path) as f:
        print(f.read())
    print('\n→ Run Cell 6 to wait for the server to become ready (~3-5 min).')
# Out:
# ✓ vLLM server is starting (PID=205)
#   Log file: /kaggle/working/vllm.log
#
# First log lines:
# [vLLM] model   = /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas
# [vLLM] n_gpus  = 2
# [vLLM] backend = XFORMERS (T4 compatible)
#
#
# → Run Cell 6 to wait for the server to become ready (~3-5 min).

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CELL 6 — Wait for server to be ready
# ═══════════════════════════════════════════════════════════════════════════════
import time, requests, subprocess

log_path = '/kaggle/working/vllm.log'
MAX_WAIT, INTERVAL = 600, 10

print(f'Polling http://localhost:8000/v1/models every {INTERVAL}s (up to {MAX_WAIT//60} min)...')
ready = False
for elapsed in range(0, MAX_WAIT, INTERVAL):
    try:
        r = requests.get('http://localhost:8000/v1/models', timeout=5)
        if r.status_code == 200:
            print(f'\n✓ Server READY after {elapsed}s!')
            print(r.json())
            ready = True
            break
    except Exception:
        pass
    time.sleep(INTERVAL)
    if elapsed % 60 == 0:
        print(f'\n── {elapsed}s elapsed — log tail ──')
        res = subprocess.run(['tail', '-n', '20', log_path], capture_output=True, text=True)
        print(res.stdout)

if not ready:
    print('\n✗ Timeout. Full log:')
    res = subprocess.run(['cat', log_path], capture_output=True, text=True)
    print(res.stdout[-10000:])
# Out:
# Polling http://localhost:8000/v1/models every 10s (up to 10 min)...
#
# ── 0s elapsed — log tail ──
# [vLLM] model   = /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas
# [vLLM] n_gpus  = 2
# [vLLM] backend = XFORMERS (T4 compatible)
#
#
# ── 60s elapsed — log tail ──
# (APIServer pid=206) INFO 06-09 19:50:09 [utils.py:344]    ▀▀  ▀▀▀▀▀ ▀▀▀▀▀ ▀     ▀
# (APIServer pid=206) INFO 06-09 19:50:09 [utils.py:344]
# (APIServer pid=206) INFO 06-09 19:50:09 [utils.py:278] non-default args: {'model_tag': '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', 'host': '0.0.0.0', 'model': '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', 'trust_remote_code': True, 'dtype': 'half', 'max_model_len': 32768, 'enforce_eager': True, 'tensor_parallel_size': 2, 'gpu_memory_utilization': 0.9, 'limit_mm_per_prompt': {'video': 1}}
# (APIServer pid=206) WARNING 06-09 19:50:09 [envs.py:2057] Unknown vLLM environment variable detected: VLLM_USE_FLASHINFER
# (APIServer pid=206) WARNING 06-09 19:50:09 [envs.py:2057] Unknown vLLM environment variable detected: VLLM_ATTENTION_BACKEND
# (APIServer pid=206) WARNING 06-09 19:50:09 [envs.py:2057] Unknown vLLM environment variable detected: VLLM_USE_V1
# (APIServer pid=206) INFO 06-09 19:50:28 [model.py:617] Resolved architecture: Qwen3VLForConditionalGeneration
# (APIServer pid=206) WARNING 06-09 19:50:28 [model.py:2090] Casting torch.bfloat16 to torch.float16.
# (APIServer pid=206) INFO 06-09 19:50:28 [model.py:1752] Using max model len 32768
# (APIServer pid=206) INFO 06-09 19:50:28 [vllm.py:977] Asynchronous scheduling is enabled.
# (APIServer pid=206) WARNING 06-09 19:50:28 [vllm.py:1033] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (APIServer pid=206) WARNING 06-09 19:50:28 [vllm.py:1058] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (APIServer pid=206) INFO 06-09 19:50:28 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (APIServer pid=206) INFO 06-09 19:50:28 [vllm.py:1234] Cudagraph is disabled under eager mode
# (APIServer pid=206) INFO 06-09 19:50:28 [compilation.py:312] Enabled custom fusions: norm_quant, act_quant
# (APIServer pid=206) [transformers] `Qwen2VLImageProcessorFast` is deprecated. The `Fast` suffix for image processors has been removed; use `Qwen2VLImageProcessor` instead.
# (APIServer pid=206) [transformers] The `use_fast` parameter is deprecated and will be removed in a future version. Use `backend="torchvision"` instead of `use_fast=True`, or `backend="pil"` instead of `use_fast=False`.
# (EngineCore pid=253) INFO 06-09 19:50:51 [core.py:112] Initializing a V1 LLM engine (v0.22.1) with config: model='/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', speculative_config=None, tokenizer='/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=2, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, quantization_config=None, enforce_eager=True, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'ir_enable_torch_wrap': False, 'splitting_ops': [], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [2048], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'size_asserts': False, 'alignment_asserts': False, 'scalar_asserts': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': True, 'fuse_act_quant': True, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'fuse_rope_kvcache_cat_mla': False, 'fuse_act_padding': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native']), enable_flashinfer_autotune=True, moe_backend='auto', linear_backend='auto')
# (EngineCore pid=253) WARNING 06-09 19:50:51 [multiproc_executor.py:1029] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore pid=253) INFO 06-09 19:50:51 [multiproc_executor.py:139] DP group leader: node_rank=0, node_rank_within_dp=0, master_addr=127.0.0.1, mq_connect_ip=172.19.2.2 (local), world_size=2, local_world_size=2
#
#
# ── 120s elapsed — log tail ──
# (Worker_TP0 pid=279) INFO 06-09 19:51:16 [gpu_model_runner.py:5037] Starting to load model /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas...
# (Worker_TP1 pid=280) ERROR 06-09 19:51:16 [fa_utils.py:171] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (Worker_TP1 pid=280) WARNING 06-09 19:51:16 [vllm.py:1033] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (Worker_TP1 pid=280) WARNING 06-09 19:51:16 [vllm.py:1058] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (Worker_TP1 pid=280) INFO 06-09 19:51:16 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (Worker_TP1 pid=280) INFO 06-09 19:51:16 [vllm.py:1234] Cudagraph is disabled under eager mode
# (Worker_TP0 pid=279) ERROR 06-09 19:51:17 [fa_utils.py:171] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [mm_encoder_attention.py:372] Using AttentionBackendEnum.TORCH_SDPA for MMEncoderAttention.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [vllm.py:977] Asynchronous scheduling is enabled.
# (Worker_TP0 pid=279) WARNING 06-09 19:51:17 [vllm.py:1033] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (Worker_TP0 pid=279) WARNING 06-09 19:51:17 [vllm.py:1058] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [vllm.py:1234] Cudagraph is disabled under eager mode
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [compilation.py:312] Enabled custom fusions: norm_quant, act_quant
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [cuda.py:378] Using TRITON_ATTN attention backend out of potential backends: ['TRITON_ATTN', 'FLEX_ATTENTION'].
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [weight_utils.py:922] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 16.33 GiB. Available RAM: 24.86 GiB.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [weight_utils.py:945] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:10<00:32, 10.83s/it]
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:24<00:24, 12.24s/it]
#
#
# ── 180s elapsed — log tail ──
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [mm_encoder_attention.py:372] Using AttentionBackendEnum.TORCH_SDPA for MMEncoderAttention.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [vllm.py:977] Asynchronous scheduling is enabled.
# (Worker_TP0 pid=279) WARNING 06-09 19:51:17 [vllm.py:1033] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (Worker_TP0 pid=279) WARNING 06-09 19:51:17 [vllm.py:1058] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [vllm.py:1234] Cudagraph is disabled under eager mode
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [compilation.py:312] Enabled custom fusions: norm_quant, act_quant
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [cuda.py:378] Using TRITON_ATTN attention backend out of potential backends: ['TRITON_ATTN', 'FLEX_ATTENTION'].
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [weight_utils.py:922] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 16.33 GiB. Available RAM: 24.86 GiB.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [weight_utils.py:945] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:10<00:32, 10.83s/it]
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:24<00:24, 12.24s/it]
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [00:39<00:13, 13.83s/it]
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:50<00:00, 12.65s/it]
# (Worker_TP0 pid=279)
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:50<00:00, 12.65s/it]
# (Worker_TP0 pid=279)
# (Worker_TP0 pid=279) INFO 06-09 19:52:07 [default_loader.py:397] Loading weights took 50.65 seconds
# (Worker_TP0 pid=279) INFO 06-09 19:52:08 [gpu_model_runner.py:5132] Model loading took 8.49 GiB memory and 51.044002 seconds
# (Worker_TP0 pid=279) INFO 06-09 19:52:09 [gpu_model_runner.py:6136] Encoder cache will be initialized with a budget of 16384 tokens, and profiled with 1 image items of the maximum feature size.
#
#
# ✓ Server READY after 240s!
# {'object': 'list', 'data': [{'id': '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', 'object': 'model', 'created': 1781034823, 'owned_by': 'vllm', 'root': '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', 'parent': None, 'max_model_len': 32768, 'permission': [{'id': 'modelperm-bbf17156e2db6533', 'object': 'model_permission', 'created': 1781034823, 'allow_create_engine': False, 'allow_sampling': True, 'allow_logprobs': True, 'allow_search_indices': False, 'allow_view': True, 'allow_fine_tuning': False, 'organization': '*', 'group': None, 'is_blocking': False}]}]}

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CELL 6.5 — Expose the vLLM server to the internet with ngrok
# ═══════════════════════════════════════════════════════════════════════════════
# The vLLM server above only listens on localhost:8000, which the Verilens Chrome
# extension (running on your own machine) can't reach. ngrok opens a public HTTPS
# tunnel to it. Copy the printed URL into the extension popup:
#     Verilens popup → "AI Video Detection" → paste URL → Test connection
#
# Get a free authtoken at: https://dashboard.ngrok.com/get-started/your-authtoken
# (Kaggle: add it as a Secret named NGROK_AUTH_TOKEN, or paste it inline below.)

# !pip install -q pyngrok

import os
from pyngrok import ngrok

# Prefer a Kaggle Secret; fall back to the inline value.
NGROK_AUTH_TOKEN = ""  # ← paste your token here if not using Kaggle Secrets
try:
    from kaggle_secrets import UserSecretsClient
    NGROK_AUTH_TOKEN = NGROK_AUTH_TOKEN or UserSecretsClient().get_secret("NGROK_AUTH_TOKEN")
except Exception:
    pass

if not NGROK_AUTH_TOKEN:
    raise SystemExit("Set NGROK_AUTH_TOKEN (inline above or as a Kaggle Secret) and re-run this cell.")

ngrok.set_auth_token(NGROK_AUTH_TOKEN)
ngrok.kill()  # drop any tunnel from a previous run
public_url = ngrok.connect(8000, "http").public_url

print("=" * 70)
print("✓ VideoVeritas is now public at:")
print("   ", public_url)
print("=" * 70)
print("\nPaste that URL into the Verilens extension:")
print("   popup → AI Video Detection → URL field → Test connection")
print("\nSanity check (should list the model):")
print(f"   curl {public_url}/v1/models -H 'ngrok-skip-browser-warning: true'")

# %% [markdown]
# ## Inference
# Update `video_path` to a file from your Kaggle Input dataset.

# %%
import base64, os, re
from openai import OpenAI

model_dir = os.environ.get('MODEL_DIR', '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas')
client    = OpenAI(api_key='EMPTY', base_url='http://localhost:8000/v1')

SYSTEM = (
    'You are an expert video analyst. Think carefully. '
    'Give your final verdict inside <answer> </answer> tags.'
)

# ↓↓↓ CHANGE THIS PATH ↓↓↓
video_path = '/kaggle/input/datasets/kanzeus/realai-video-dataset/real/real (23).mp4'

if not os.path.exists(video_path):
    print(f"Not found: '{video_path}'")
    print("Available videos:")
    # !find /kaggle/input -name '*.mp4' -o -name '*.avi' | head -20
else:
    ext = os.path.splitext(video_path)[1].lstrip('.') or 'mp4'
    print(f'Reading {os.path.getsize(video_path)/1e6:.1f} MB: {video_path}')
    with open(video_path, 'rb') as f:
        b64 = base64.b64encode(f.read()).decode()

    resp = client.chat.completions.create(
        model=model_dir,
        messages=[
            {'role': 'system', 'content': SYSTEM},
            {'role': 'user', 'content': [
                {'type': 'video_url', 'video_url': {'url': f'data:video/{ext};base64,{b64}'}},
                {'type': 'text', 'text': 'Is this video real or AI-generated/fake?'},
            ]},
        ],
        temperature=0.7,
        extra_body={
            'mm_processor_kwargs': {
                'fps': 2,
                # max_pixels caps each frame's resolution before tokenisation.
                # 360×420 = 151200 px/frame keeps token count manageable on T4.
                # Qwen3VL accepts: fps, min_pixels, max_pixels, total_pixels
                # do_sample_frames is NOT valid for Qwen3VL — removing it was the fix.
                'max_pixels': 360 * 420,
            }
        },
    )
    content = resp.choices[0].message.content
    print('\n--- RESPONSE ---\n', content)
    m = re.search(r'<answer>(.*?)</answer>', content, re.DOTALL)
    if m:
        print(f'\n🔍 VERDICT: {m.group(1).strip()}')
# Out:
# Reading 5.6 MB: /kaggle/input/datasets/kanzeus/realai-video-dataset/real/real (23).mp4
#
# --- RESPONSE ---
#  <answer>real</answer>
#
# 🔍 VERDICT: real

# %%
# # ═══════════════════════════════════════════════════════════════════════════════
# # CELL 8 — Batch inference
# # ═══════════════════════════════════════════════════════════════════════════════
# import base64, os, json, re
# from pathlib import Path
# from openai import OpenAI

# model_dir = os.environ.get('MODEL_DIR', '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas')
# client    = OpenAI(api_key='EMPTY', base_url='http://localhost:8000/v1')

# # ↓↓↓ Change this path ↓↓↓
# VIDEO_FOLDER = '/kaggle/input/your-dataset/'
# EXTS = {'.mp4', '.avi', '.mov', '.mkv', '.webm'}

# videos = [p for p in Path(VIDEO_FOLDER).rglob('*') if p.suffix.lower() in EXTS]
# if not videos:
#     print(f'No videos found in {VIDEO_FOLDER}')
# else:
#     results = []
#     for vp in videos:
#         print(f'{vp.name}... ', end='', flush=True)
#         try:
#             with open(vp, 'rb') as f:
#                 b64 = base64.b64encode(f.read()).decode()
#             ext = vp.suffix.lstrip('.')
#             resp = client.chat.completions.create(
#                 model=model_dir,
#                 messages=[
#                     {'role': 'system', 'content': 'Analyze video. Verdict in <answer></answer>.'},
#                     {'role': 'user', 'content': [
#                         {'type': 'video_url', 'video_url': {'url': f'data:video/{ext};base64,{b64}'}},
#                         {'type': 'text', 'text': 'Real or AI-generated?'},
#                     ]},
#                 ],
#                 temperature=0.3,
#                 extra_body={'mm_processor_kwargs': {'fps': 2, 'do_sample_frames': True}},
#             )
#             content = resp.choices[0].message.content
#             m = re.search(r'<answer>(.*?)</answer>', content, re.DOTALL)
#             verdict = m.group(1).strip() if m else 'UNKNOWN'
#             results.append({'file': str(vp), 'verdict': verdict})
#             print(verdict)
#         except Exception as e:
#             print(f'ERROR: {e}')
#             results.append({'file': str(vp), 'verdict': 'ERROR', 'error': str(e)})

#     out = '/kaggle/working/results.json'
#     with open(out, 'w') as f:
#         json.dump(results, f, indent=2)
#     print(f'\n✓ Saved to {out}')
#     import pandas as pd
#     display(pd.DataFrame(results))

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CELL 9 — Diagnostics (run any time)
# ═══════════════════════════════════════════════════════════════════════════════
import subprocess

print('='*60)
print('VLLM LOG')
print('='*60)
# !cat /kaggle/working/vllm.log

print('\n' + '='*60)
print('ENVIRONMENT')
print('='*60)
# !python -c "import vllm; print('vLLM:', vllm.__version__)"
# !python -c "import torch; print('torch:', torch.__version__, 'CUDA:', torch.version.cuda)"
# !python -c "import xformers; print('xformers:', xformers.__version__)"
# !python -m pip show flashinfer 2>/dev/null && echo 'WARNING: flashinfer still installed!' || echo '✓ flashinfer not present'

print('\n' + '='*60)
print('GPU')
print('='*60)
# !nvidia-smi

print('\n' + '='*60)
print('DISK')
print('='*60)
# !df -h /root /kaggle/working
# Out:
# ============================================================
# VLLM LOG
# ============================================================
# [vLLM] model   = /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas
# [vLLM] n_gpus  = 2
# [vLLM] backend = XFORMERS (T4 compatible)
#
#
#
#
#
# (APIServer pid=206) INFO 06-09 19:50:09 [utils.py:344]
# (APIServer pid=206) INFO 06-09 19:50:09 [utils.py:278] non-default args: {'model_tag': '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', 'host': '0.0.0.0', 'model': '/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', 'trust_remote_code': True, 'dtype': 'half', 'max_model_len': 32768, 'enforce_eager': True, 'tensor_parallel_size': 2, 'gpu_memory_utilization': 0.9, 'limit_mm_per_prompt': {'video': 1}}
# (APIServer pid=206) WARNING 06-09 19:50:09 [envs.py:2057] Unknown vLLM environment variable detected: VLLM_USE_FLASHINFER
# (APIServer pid=206) WARNING 06-09 19:50:09 [envs.py:2057] Unknown vLLM environment variable detected: VLLM_ATTENTION_BACKEND
# (APIServer pid=206) WARNING 06-09 19:50:09 [envs.py:2057] Unknown vLLM environment variable detected: VLLM_USE_V1
# (APIServer pid=206) INFO 06-09 19:50:28 [model.py:617] Resolved architecture: Qwen3VLForConditionalGeneration
# (APIServer pid=206) WARNING 06-09 19:50:28 [model.py:2090] Casting torch.bfloat16 to torch.float16.
# (APIServer pid=206) INFO 06-09 19:50:28 [model.py:1752] Using max model len 32768
# (APIServer pid=206) INFO 06-09 19:50:28 [vllm.py:977] Asynchronous scheduling is enabled.
# (APIServer pid=206) WARNING 06-09 19:50:28 [vllm.py:1033] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (APIServer pid=206) WARNING 06-09 19:50:28 [vllm.py:1058] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (APIServer pid=206) INFO 06-09 19:50:28 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (APIServer pid=206) INFO 06-09 19:50:28 [vllm.py:1234] Cudagraph is disabled under eager mode
# (APIServer pid=206) INFO 06-09 19:50:28 [compilation.py:312] Enabled custom fusions: norm_quant, act_quant
# (APIServer pid=206) [transformers] `Qwen2VLImageProcessorFast` is deprecated. The `Fast` suffix for image processors has been removed; use `Qwen2VLImageProcessor` instead.
# (APIServer pid=206) [transformers] The `use_fast` parameter is deprecated and will be removed in a future version. Use `backend="torchvision"` instead of `use_fast=True`, or `backend="pil"` instead of `use_fast=False`.
# (EngineCore pid=253) INFO 06-09 19:50:51 [core.py:112] Initializing a V1 LLM engine (v0.22.1) with config: model='/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', speculative_config=None, tokenizer='/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=2, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, quantization_config=None, enforce_eager=True, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=/root/.cache/modelscope/hub/models/EricTanh/VideoVeritas, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'ir_enable_torch_wrap': False, 'splitting_ops': [], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [2048], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'size_asserts': False, 'alignment_asserts': False, 'scalar_asserts': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': True, 'fuse_act_quant': True, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'fuse_rope_kvcache_cat_mla': False, 'fuse_act_padding': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native']), enable_flashinfer_autotune=True, moe_backend='auto', linear_backend='auto')
# (EngineCore pid=253) WARNING 06-09 19:50:51 [multiproc_executor.py:1029] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore pid=253) INFO 06-09 19:50:51 [multiproc_executor.py:139] DP group leader: node_rank=0, node_rank_within_dp=0, master_addr=127.0.0.1, mq_connect_ip=172.19.2.2 (local), world_size=2, local_world_size=2
# [transformers] `Qwen2VLImageProcessorFast` is deprecated. The `Fast` suffix for image processors has been removed; use `Qwen2VLImageProcessor` instead.
# [transformers] `Qwen2VLImageProcessorFast` is deprecated. The `Fast` suffix for image processors has been removed; use `Qwen2VLImageProcessor` instead.
# (Worker pid=279) INFO 06-09 19:51:09 [parallel_state.py:1422] world_size=2 rank=0 local_rank=0 distributed_init_method=tcp://127.0.0.1:40849 backend=nccl
# (Worker pid=280) INFO 06-09 19:51:09 [parallel_state.py:1422] world_size=2 rank=1 local_rank=1 distributed_init_method=tcp://127.0.0.1:40849 backend=nccl
# (Worker pid=279) INFO 06-09 19:51:09 [pynccl.py:113] vLLM is using nccl==2.28.9
# (Worker pid=279) WARNING 06-09 19:51:10 [symm_mem.py:66] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=280) WARNING 06-09 19:51:10 [symm_mem.py:66] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=279) WARNING 06-09 19:51:10 [custom_all_reduce.py:164] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (Worker pid=280) WARNING 06-09 19:51:10 [custom_all_reduce.py:164] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (Worker pid=279) INFO 06-09 19:51:10 [cuda_communicator.py:232] Using ['PYNCCL'] all-reduce backends (in dispatch order) for group 'tp:0' out of potential backends: ['NCCL_SYMM_MEM', 'QUICK_REDUCE', 'FLASHINFER', 'CUSTOM', 'SYMM_MEM', 'PYNCCL'].
# (Worker pid=279) INFO 06-09 19:51:10 [parallel_state.py:1735] rank 0 in world size 2 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (Worker pid=279) INFO 06-09 19:51:10 [topk_topp_sampler.py:70] FlashInfer top-p/top-k sampling disabled via VLLM_USE_FLASHINFER_SAMPLER=0; using PyTorch-native sampler.
# (Worker pid=280) [transformers] The `use_fast` parameter is deprecated and will be removed in a future version. Use `backend="torchvision"` instead of `use_fast=True`, or `backend="pil"` instead of `use_fast=False`.
# (Worker pid=279) [transformers] The `use_fast` parameter is deprecated and will be removed in a future version. Use `backend="torchvision"` instead of `use_fast=True`, or `backend="pil"` instead of `use_fast=False`.
# (Worker_TP0 pid=279) INFO 06-09 19:51:16 [gpu_model_runner.py:5037] Starting to load model /root/.cache/modelscope/hub/models/EricTanh/VideoVeritas...
# (Worker_TP1 pid=280) ERROR 06-09 19:51:16 [fa_utils.py:171] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (Worker_TP1 pid=280) WARNING 06-09 19:51:16 [vllm.py:1033] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (Worker_TP1 pid=280) WARNING 06-09 19:51:16 [vllm.py:1058] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (Worker_TP1 pid=280) INFO 06-09 19:51:16 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (Worker_TP1 pid=280) INFO 06-09 19:51:16 [vllm.py:1234] Cudagraph is disabled under eager mode
# (Worker_TP0 pid=279) ERROR 06-09 19:51:17 [fa_utils.py:171] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [mm_encoder_attention.py:372] Using AttentionBackendEnum.TORCH_SDPA for MMEncoderAttention.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [vllm.py:977] Asynchronous scheduling is enabled.
# (Worker_TP0 pid=279) WARNING 06-09 19:51:17 [vllm.py:1033] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (Worker_TP0 pid=279) WARNING 06-09 19:51:17 [vllm.py:1058] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [vllm.py:1234] Cudagraph is disabled under eager mode
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [compilation.py:312] Enabled custom fusions: norm_quant, act_quant
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [cuda.py:378] Using TRITON_ATTN attention backend out of potential backends: ['TRITON_ATTN', 'FLEX_ATTENTION'].
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [weight_utils.py:922] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 16.33 GiB. Available RAM: 24.86 GiB.
# (Worker_TP0 pid=279) INFO 06-09 19:51:17 [weight_utils.py:945] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:10<00:32, 10.83s/it]
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:24<00:24, 12.24s/it]
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [00:39<00:13, 13.83s/it]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:50<00:00, 12.65s/it]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:50<00:00, 12.65s/it]
# (Worker_TP0 pid=279)
# (Worker_TP0 pid=279) INFO 06-09 19:52:07 [default_loader.py:397] Loading weights took 50.65 seconds
# (Worker_TP0 pid=279) INFO 06-09 19:52:08 [gpu_model_runner.py:5132] Model loading took 8.49 GiB memory and 51.044002 seconds
# (Worker_TP0 pid=279) INFO 06-09 19:52:09 [gpu_model_runner.py:6136] Encoder cache will be initialized with a budget of 16384 tokens, and profiled with 1 image items of the maximum feature size.
# (Worker_TP0 pid=279) INFO 06-09 19:53:07 [gpu_worker.py:466] Available KV cache memory: 2.74 GiB
# (EngineCore pid=253) INFO 06-09 19:53:07 [kv_cache_utils.py:1733] GPU KV cache size: 39,936 tokens
# (EngineCore pid=253) INFO 06-09 19:53:07 [kv_cache_utils.py:1734] Maximum concurrency for 32,768 tokens per request: 1.22x
# (Worker_TP1 pid=280) INFO 06-09 19:53:08 [jit_monitor.py:54] Kernel JIT monitor activated — Triton JIT compilations during inference will be logged as warnings.
# (Worker_TP0 pid=279) INFO 06-09 19:53:08 [jit_monitor.py:54] Kernel JIT monitor activated — Triton JIT compilations during inference will be logged as warnings.
# (EngineCore pid=253) INFO 06-09 19:53:08 [core.py:309] init engine (profile, create kv cache, warmup model) took 59.81 s
# (EngineCore pid=253) [transformers] `Qwen2VLImageProcessorFast` is deprecated. The `Fast` suffix for image processors has been removed; use `Qwen2VLImageProcessor` instead.
# (EngineCore pid=253) [transformers] The `use_fast` parameter is deprecated and will be removed in a future version. Use `backend="torchvision"` instead of `use_fast=True`, or `backend="pil"` instead of `use_fast=False`.
# (EngineCore pid=253) INFO 06-09 19:53:16 [vllm.py:977] Asynchronous scheduling is enabled.
# (EngineCore pid=253) WARNING 06-09 19:53:16 [vllm.py:1033] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (EngineCore pid=253) WARNING 06-09 19:53:16 [vllm.py:1058] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (EngineCore pid=253) INFO 06-09 19:53:16 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (EngineCore pid=253) INFO 06-09 19:53:16 [vllm.py:1234] Cudagraph is disabled under eager mode
# (EngineCore pid=253) INFO 06-09 19:53:16 [compilation.py:312] Enabled custom fusions: norm_quant, act_quant
# (APIServer pid=206) INFO 06-09 19:53:16 [api_server.py:592] Supported tasks: ['generate']
# (APIServer pid=206) WARNING 06-09 19:53:17 [model.py:1509] Default vLLM sampling parameters have been overridden by the model's `generation_config.json`: `{'temperature': 0.7, 'top_k': 20, 'top_p': 0.8}`. If this is not intended, please relaunch vLLM instance with `--generation-config vllm`.
# (APIServer pid=206) INFO 06-09 19:53:18 [hf.py:488] Detected the chat template content format to be 'openai'. You can set `--chat-template-content-format` to override this.
# (APIServer pid=206) INFO 06-09 19:53:33 [base.py:224] Multi-modal warmup completed in 14.958s
# (APIServer pid=206) INFO 06-09 19:53:35 [base.py:224] Readonly multi-modal warmup completed in 2.347s
# (APIServer pid=206) INFO 06-09 19:53:35 [api_server.py:596] Starting vLLM server on http://0.0.0.0:8000
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:37] Available routes are:
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /openapi.json, Methods: HEAD, GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /docs, Methods: HEAD, GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /docs/oauth2-redirect, Methods: HEAD, GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /redoc, Methods: HEAD, GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /tokenize, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /detokenize, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /load, Methods: GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /version, Methods: GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /health, Methods: GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /metrics, Methods: GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/models, Methods: GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /ping, Methods: GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /ping, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /invocations, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/chat/completions, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/chat/completions/batch, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/responses, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/responses/{response_id}, Methods: GET
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/responses/{response_id}/cancel, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/completions, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/messages, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/messages/count_tokens, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /inference/v1/generate, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /scale_elastic_ep, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /is_scaling_elastic_ep, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /generative_scoring, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/chat/completions/render, Methods: POST
# (APIServer pid=206) INFO 06-09 19:53:35 [launcher.py:46] Route: /v1/completions/render, Methods: POST
# (APIServer pid=206) INFO:     Started server process [206]
# (APIServer pid=206) INFO:     Waiting for application startup.
# (APIServer pid=206) INFO:     Application startup complete.
# (APIServer pid=206) INFO:     127.0.0.1:51876 - "GET /v1/models HTTP/1.1" 200 OK
# (Worker_TP0 pid=279) WARNING 06-09 19:54:02 [jit_monitor.py:103] Triton kernel JIT compilation during inference: _compute_slot_mapping_kernel. This causes a latency spike; consider extending warmup to cover this shape/config.
# (Worker_TP0 pid=279) WARNING 06-09 19:54:03 [jit_monitor.py:103] Triton kernel JIT compilation during inference: _bilinear_pos_embed_kernel. This causes a latency spike; consider extending warmup to cover this shape/config.
# (Worker_TP0 pid=279) WARNING 06-09 19:54:09 [jit_monitor.py:103] Triton kernel JIT compilation during inference: kernel_unified_attention. This causes a latency spike; consider extending warmup to cover this shape/config.
# (Worker_TP0 pid=279) WARNING 06-09 19:54:34 [jit_monitor.py:103] Triton kernel JIT compilation during inference: _triton_mrope_forward. This causes a latency spike; consider extending warmup to cover this shape/config.
# (Worker_TP0 pid=279) WARNING 06-09 19:54:43 [jit_monitor.py:103] Triton kernel JIT compilation during inference: reduce_segments. This causes a latency spike; consider extending warmup to cover this shape/config.
# (APIServer pid=206) INFO:     127.0.0.1:51890 - "POST /v1/chat/completions HTTP/1.1" 200 OK
#
# ============================================================
# ENVIRONMENT
# ============================================================
# vLLM: 0.22.1
# torch: 2.11.0+cu130 CUDA: 13.0
# xformers: 0.0.35
# ✓ flashinfer not present
#
# ============================================================
# GPU
# ============================================================
# Tue Jun  9 19:54:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0             32W /   70W |   13969MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   55C    P0             29W /   70W |   13969MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A             279      C   VLLM::Worker_TP0                      13966MiB |
# |    1   N/A  N/A             280      C   VLLM::Worker_TP1                      13966MiB |
# +-----------------------------------------------------------------------------------------+
#
# ============================================================
# DISK
# ============================================================
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         7.9T  6.9T  1.1T  87% /
# /dev/loop1       20G   41M   20G   1% /kaggle/working
